# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ConvNeXtBase
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # VGG16

# %%
img_width = 224
img_height = 224

train_dir = '/home/kirill/Рабочий стол/Python projects/ML/datasets/arnold_and_vin/train/'
val_dir = '/home/kirill/Рабочий стол/Python projects/ML/datasets/arnold_and_vin/val/'
test_dir = '/home/kirill/Рабочий стол/Python projects/ML/datasets/arnold_and_vin/test/'

input_shape = (img_width, img_height, 3)

# %%
vgg16_net = VGG16(weights='imagenet', include_top=True, input_shape=input_shape)
vgg16_net.trainable = False
# Out:
# 2024-07-06 17:18:32.006976: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2024-07-06 17:18:32.313295: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2024-07-06 17:18:35.126021: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.
# 2024-07-06 17:18:46.886264: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 411041792 exceeds 10% of free system memory.

# %%
vgg16_net.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ...

# %%
model = Sequential(vgg16_net.layers[:-1])
model.add(Dense(2, activation='softmax'))

# %%
model.build((None,) + input_shape)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ...

# %%
# model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=1e-5), metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(rescale=1./255)
val_generator = datagen.flow_from_directory(
        val_dir + '100/',
        target_size=(224, 224),
        class_mode='categorical',
        shuffle=True
    )
# Out:
# Found 100 images belonging to 2 classes.

# %%
im = Image.fromarray(np.array(val_generator[0][0][5]*255, dtype =np.uint8))
plt.imshow(im)

# %%
im = Image.fromarray(np.array(val_generator[1][0][0]*255, dtype =np.uint8))
plt.imshow(im)

# %%
def study(epochs, img_size, train_dir, val_dir, test_dir, learning_rate=1e-3):
    # vgg16_net = VGG16(weights='imagenet', include_top=True, input_shape=input_shape)
    # vgg16_net.trainable = False
    global vgg16_net
    model = Sequential(vgg16_net.layers[:-1])
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))
    model.build((None,) + input_shape)
    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(learning_rate=ExponentialDecay(learning_rate, decay_rate=0.1, decay_steps=7)),
                  metrics=['accuracy'])
    # model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True), metrics=['accuracy'])
    
    datagen = ImageDataGenerator(rescale=1./255)
    # steps_per_epoch = max(int(train_images_amount/epochs/batch_size), 1)
    # print('total train_images_count:', steps_per_epoch*epochs*batch_size)

    # if val_images_amount==None:
    #     validation_steps = None
    # else:
    #     validation_steps = max(int(val_images_amount/batch_size/epochs), 1)
    #     print('total val_images_count:', validation_steps*epochs*batch_size)

    # print()
    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=img_size,
        # batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    val_generator = datagen.flow_from_directory(
        val_dir,
        target_size=img_size,
        class_mode='categorical',
        shuffle=True
    )

    test_generator = datagen.flow_from_directory(
        test_dir,
        target_size=(img_width, img_height),
        batch_size=100,
        class_mode='categorical',
        shuffle=True
    )

    model.fit(
      train_generator,
      # steps_per_epoch=steps_per_epoch,
      epochs=epochs,
      # validation_split = 0.2,
      validation_data=val_generator,
      # validation_steps=validation_steps
    )

    print('\ntest:\n')
    res = model.evaluate(test_generator, steps = 1)
    print('-'*80)

    return model

# %%
study(12, (img_width, img_height), train_dir + '800/', val_dir + '100/', test_dir, learning_rate=1e-2)
# Out:
# Found 800 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 1271 images belonging to 2 classes.
# Epoch 1/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 126s 5s/step - accuracy: 0.4607 - loss: 6.6122 - val_accuracy: 0.5000 - val_loss: 2.0836
# Epoch 2/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 140s 5s/step - accuracy: 0.5036 - loss: 2.0662 - val_accuracy: 0.5000 - val_loss: 2.0684
# Epoch 3/12
#  7/25 ━━━━━━━━━━━━━━━━━━━━ 1:22 5s/step - accuracy: 0.5463 - loss: 2.0251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 study(12, (img_width, img_height), train_dir + '800/', val_dir + '100/', test_dir, learning_rate=1e-2)
#
# Cell In[86], line 48, in study(epochs, img_size, train_dir, val_dir, test_dir, learning_rate)
#      33 val_generator = datagen.flow_from_directory(
#      34     val_dir,
#      35     target_size=img_size,
# ...

# %% [markdown]
# # resnet50

# %%
resnet50 = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
resnet50.trainable = False
# Out:
# 2024-07-06 14:00:24.901922: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-06 14:00:26.460273: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
resnet50.summary()

# %%
l1 = Flatten()(resnet50.output)
l2 = Dense(2, activation='softmax')(l1)

model = Model(inputs=resnet50.input, outputs=l2)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ...

# %%
def study_resnet50(epochs, img_size, train_dir, val_dir, test_dir, learning_rate=1e-3):
    global resnet50
    l1 = Flatten()(resnet50.output)
    l2 = Dropout(0.5)(l1)
    l3 = Dense(2, activation='softmax')(l2)
    model = Model(inputs=resnet50.input, outputs=l2)
    model.build((None,) + input_shape)
    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=img_size,
        # batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    val_generator = datagen.flow_from_directory(
        val_dir,
        target_size=img_size,
        # batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    test_generator = datagen.flow_from_directory(
        test_dir,
        target_size=(img_width, img_height),
        batch_size=100,
        class_mode='categorical',
        shuffle=True
    )

    model.fit(
      train_generator,
      epochs=epochs,
      validation_data=val_generator,
    )

    print('\ntest:\n')
    res = model.evaluate(test_generator, steps = 1)
    print('-'*80)

    return model

# %%
m = study_resnet50(6, (img_width, img_height), train_dir + '3000/', val_dir + '1200/', test_dir)
# Out:
# Found 3000 images belonging to 2 classes.
# Found 1200 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.
# Epoch 1/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.5469 - loss: 2.5925 - val_accuracy: 0.5592 - val_loss: 0.8719
# Epoch 2/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - accuracy: 0.6660 - loss: 0.6420 - val_accuracy: 0.6458 - val_loss: 0.7147
# Epoch 3/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.7326 - loss: 0.5842 - val_accuracy: 0.7183 - val_loss: 0.5798
# Epoch 4/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.7713 - loss: 0.4689 - val_accuracy: 0.7417 - val_loss: 0.5331
# Epoch 5/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.7717 - loss: 0.4903 - val_accuracy: 0.6467 - val_loss: 0.7944
# Epoch 6/6
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.7156 - loss: 0.7197 - val_accuracy: 0.7183 - val_loss: 0.5987
#
# test:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9500 - loss: 0.1945
# ...

# %%
train_dir = '/home/kirill/Рабочий стол/bp/train/'
val_dir = '/home/kirill/Рабочий стол/bp/val/'
# test_dir = '/home/kirill/Рабочий стол/Python projects/ML/datasets/arnold_and_vin/test/'

# %%
m2 = study_resnet50(14, (img_width, img_height), train_dir, val_dir)
# Out:
# Found 276 images belonging to 2 classes.
# Found 32 images belonging to 2 classes.
# Found 276 images belonging to 2 classes.
# Epoch 1/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.5402 - loss: 4.9177 - val_accuracy: 0.5000 - val_loss: 4.4883
# Epoch 2/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5120 - loss: 3.0822 - val_accuracy: 0.5625 - val_loss: 2.1578
# Epoch 3/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6214 - loss: 1.4619 - val_accuracy: 0.5938 - val_loss: 1.1862
# Epoch 4/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6826 - loss: 0.9179 - val_accuracy: 0.6562 - val_loss: 1.1207
# Epoch 5/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7880 - loss: 0.5952 - val_accuracy: 0.7188 - val_loss: 0.9264
# Epoch 6/14
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8402 - loss: 0.5073 - val_accuracy: 0.6875 - val_loss: 0.7607
# Epoch 7/14
# ...

# %% [markdown]
# # ConvNeXtBase

# %%
conv = ConvNeXtBase(weights='imagenet', include_top=False, input_shape=input_shape)
conv.trainable = False

# %%
def study_conv(epochs, img_size, train_dir, val_dir, test_dir, learning_rate=1e-3):
    global conv
    l1 = Flatten()(resnet50.output)
    l2 = Dropout(0.5)(l1)
    l3 = Dense(2, activation='softmax')(l2)
    model = Model(inputs=resnet50.input, outputs=l3)
    model.build((None,) + input_shape)
    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=learning_rate), metrics=['accuracy'])

    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_directory(
        train_dir,
        target_size=img_size,
        # batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    val_generator = datagen.flow_from_directory(
        val_dir,
        target_size=img_size,
        # batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    test_generator = datagen.flow_from_directory(
        test_dir,
        target_size=(img_width, img_height),
        batch_size=100,
        class_mode='categorical',
        shuffle=True
    )

    model.fit(
      train_generator,
      epochs=epochs,
      validation_data=val_generator,
    )

    print('\ntest:\n')
    res = model.evaluate(test_generator, steps = 1)
    print('-'*80)

    return model

# %%
m = study_conv(12, (img_width, img_height), train_dir + '800/', val_dir + '100/', test_dir)
# Out:
# Found 800 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 1271 images belonging to 2 classes.
# Epoch 1/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.5174 - loss: 3.5361 - val_accuracy: 0.5400 - val_loss: 1.5362
# Epoch 2/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5904 - loss: 1.1162 - val_accuracy: 0.6800 - val_loss: 0.7602
# Epoch 3/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.6921 - loss: 0.7518 - val_accuracy: 0.7000 - val_loss: 0.6870
# Epoch 4/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.6833 - loss: 0.7350 - val_accuracy: 0.6400 - val_loss: 0.7575
# Epoch 5/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7161 - loss: 0.6433 - val_accuracy: 0.6200 - val_loss: 0.8635
# Epoch 6/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.6931 - loss: 0.6607 - val_accuracy: 0.6900 - val_loss: 0.7903
# Epoch 7/12
# ...
